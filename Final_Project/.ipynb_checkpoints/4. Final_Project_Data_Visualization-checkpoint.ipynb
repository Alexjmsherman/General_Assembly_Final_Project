# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# Conclusions
# -Remove Airport_list
# -trains_list correlated with subway_list

# %%
data = pd.read_csv(r'C:\Users\alsherman\Desktop\GitHub\DataScience_GeneralAssembly\Data\Cleaned_Data_May_13.csv')

# %%
#Clean up data by removing missing values
data = data[data.airport_list >= 0]
data = data[data.price >=0]
# Out:
# 1159

# %%
data.describe()
# Out:
#                  ID    latitude  location_data_accuracy   longitude  \
# count  1.159000e+03  884.000000              884.000000  884.000000
# mean   4.977594e+09   38.905641                1.009050  -77.111814
# std    7.785255e+06    0.122161                3.990919    0.173642
# min    4.959352e+09   37.815395                0.000000  -77.794018
# 25%    4.972459e+09   38.840418                0.000000  -77.132095
# 50%    4.977403e+09   38.897776                0.000000  -77.084152
# 75%    4.984580e+09   38.961652                0.000000  -77.033800
# max    4.989173e+09   39.284757               22.000000  -75.550500
#
#        average_image_size      bedroom   cat   dog  image_number        price  \
# count         1159.000000  1159.000000  1159  1159   1159.000000  1159.000000
# mean        212691.975841     2.006903     0     0      9.062985  1991.364107
# std         110451.268709     1.284942     0     0      7.437036   902.790521
# min              0.000000     0.000000     0     0      0.000000     2.000000
# 25%         270000.000000     1.000000     0     0      3.000000  1500.000000
# 50%         270000.000000     2.000000     0     0      8.000000  1800.000000
# 75%         270000.000000     3.000000     0     0     13.000000  2317.500000
# max         270000.000000     6.000000     0     0     24.000000  9851.000000
#
#        grocery_list     gym_list  movie_theatre_list  train_station_list  \
# count   1159.000000  1159.000000         1159.000000         1159.000000
# mean       9.849008     7.011217            1.094909            2.132010
# std        8.280623     7.237929            1.706829            3.723473
# min        0.000000     0.000000            0.000000            0.000000
# 25%        0.000000     0.000000            0.000000            0.000000
# 50%        9.000000     4.000000            0.000000            0.000000
# 75%       20.000000    14.000000            2.000000            3.000000
# max       20.000000    20.000000            9.000000           20.000000
#
#        airport_list  subway_station_list  Barnes_and_Nobles_list  \
# count          1159          1159.000000             1159.000000
# mean              0             1.496980                0.198447
# std               0             2.967256                0.537342
# min               0             0.000000                0.000000
# 25%               0             0.000000                0.000000
# 50%               0             0.000000                0.000000
# 75%               0             2.000000                0.000000
# max               0            18.000000                3.000000
#
#        Deloitte_list  Starbucks_list     smokings
# count    1159.000000     1159.000000  1159.000000
# mean        0.723900        3.468507     0.598792
# std         1.396284        5.167204     0.490355
# min         0.000000        0.000000     0.000000
# 25%         0.000000        0.000000     0.000000
# 50%         0.000000        1.000000     1.000000
# 75%         1.000000        5.000000     1.000000
# max         6.000000       20.000000     1.000000

# %%
data.columns
# Out:
# Index([u'ID', u'city', u'country', u'latitude', u'location_data_accuracy', u'longitude', u'state', u'availability', u'average_image_size', u'bathroom', u'bedroom', u'cat', u'date_available', u'description', u'dog', u'housing_type', u'image_number', u'laundry', u'parking', u'price', u'smoking', u'square_footage', u'time_of_posting', u'url', u'grocery_list', u'gym_list', u'movie_theatre_list', u'train_station_list', u'airport_list', u'subway_station_list', u'Barnes_and_Nobles_list', u'Deloitte_list', u'Starbucks_list', u'smokings'], dtype='object')

# %%
data[['price']].plot(kind='box')

# %%
from pandas.tools.plotting import parallel_coordinates

parallel_coordinates(data[[u'subway_station_list',u'Barnes_and_Nobles_list',
                     u'Starbucks_list', u'smokings']], 'ID')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-84bca7a857b9> in <module>()
#       2
#       3 parallel_coordinates(data[[u'subway_station_list',u'Barnes_and_Nobles_list',
# ----> 4                      u'Starbucks_list', u'smokings']], 'ID')
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\util\decorators.pyc in wrapper(*args, **kwargs)
#      86                 else:
#      87                     kwargs[new_arg_name] = new_arg_value
# ---> 88             return func(*args, **kwargs)
#      89         return wrapper
#      90     return _deprecate_kwarg
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\util\decorators.pyc in wrapper(*args, **kwargs)
#      86                 else:
#      87                     kwargs[new_arg_name] = new_arg_value
# ---> 88             return func(*args, **kwargs)
#      89         return wrapper
#      90     return _deprecate_kwarg
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in parallel_coordinates(frame, class_column, cols, ax, color, use_columns, xticks, colormap, axvlines, **kwds)
#     623
#     624     n = len(frame)
# --> 625     classes = frame[class_column].drop_duplicates()
#     626     class_col = frame[class_column]
#     627
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\core\frame.pyc in __getitem__(self, key)
#    1785             return self._getitem_multilevel(key)
#    1786         else:
# -> 1787             return self._getitem_column(key)
#    1788
#    1789     def _getitem_column(self, key):
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\core\frame.pyc in _getitem_column(self, key)
#    1792         # get column
#    1793         if self.columns.is_unique:
# -> 1794             return self._get_item_cache(key)
#    1795
#    1796         # duplicate columns & possible reduce dimensionaility
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1077         res = cache.get(item)
#    1078         if res is None:
# -> 1079             values = self._data.get(item)
#    1080             res = self._box_item_values(item, values)
#    1081             cache[item] = res
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\core\internals.pyc in get(self, item, fastpath)
#    2841
#    2842             if not isnull(item):
# -> 2843                 loc = self.items.get_loc(item)
#    2844             else:
#    2845                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\core\index.pyc in get_loc(self, key, method)
#    1435         """
#    1436         if method is None:
# -> 1437             return self._engine.get_loc(_values_from_object(key))
#    1438
#    1439         indexer = self.get_indexer([key], method=method)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:3824)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:3704)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12349)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12300)()
#
# KeyError: 'ID'

# %%
#data[[u'train_station_list',u'subway_station_list',u'Starbucks_list']].plot(kind='box', by='dog')
#data[[u'train_station_list',u'subway_station_list',u'Starbucks_list']].boxplot(by=data.cat)
from pandas.tools.plotting import scatter_matrix
scatter_matrix(data[[u'subway_station_list',u'Barnes_and_Nobles_list',
                     u'Starbucks_list', u'smokings']], alpha=0.2, figsize=(12, 12), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000035BE9E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000033800668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002A7270F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003832C2E8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000332EBF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003701DA90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000036728198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000036BF6908>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000026522048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000037A56898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003597B588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002AA7DF28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000002667E6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000033D30438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002AC86BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000039A8BB38>]], dtype=object)

# %%
data[[u'grocery_list', u'gym_list', u'movie_theatre_list', u'train_station_list',
      u'subway_station_list', u'Barnes_and_Nobles_list', u'Deloitte_list',
      u'Starbucks_list']].hist(sharex=True, sharey=True, alpha=0.5, bins=5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000044949DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000046E020B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000047B04748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000047BA9C18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004BC01748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000048926240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000004B1E8550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004ADDD080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000004ACBA198>]], dtype=object)

# %%
data[[u'grocery_list', u'gym_list',u'subway_station_list',
      u'Barnes_and_Nobles_list',u'Starbucks_list']].hist(sharex=True, sharey=True, alpha=0.5, bins=5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000439EC3C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000003F90E710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000040478E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000042C800F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000004C7A7BE0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000042C7F6D8>]], dtype=object)

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

df2.plot(kind='bar');

# %%
data.plot(x='image_number', y='price')

# %%
data[data.image_number>0].price.hist(by=data.image_number, sharex=True, sharey=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001BDEE1D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001FBBF780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001FCD97F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001FD770F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001FE6ABA8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001EF668D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002000DBA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002011B6D8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000201BEB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000202986A0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000020373E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002047CA58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000020498EB8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002062BA20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000206B2550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000207F0400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000208EAF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000020562E48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000020A4AFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000020B56B00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000020C6BF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000020D37AC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000020E20320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000020F1BF28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000020F37C88>]], dtype=object)

# %%
data.plot(kind='scatter', x='Starbucks_list', y='subway_station_list')

# %%
data.plot(kind='scatter', x='subway_station_list', y='price')

# %%
data.plot(kind='scatter', x='movie_theatre_list', y='price')

# %%
data.price.hist()

# %%
data.price.hist(by=data.bedroom, sharey=True, sharex=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000010B18A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010D6EB38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010DEBDA0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000000010EE1400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010FDEB00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010F99E10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000001114AD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011299780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000011381710>]], dtype=object)

# %%
data.plot(kind='scatter', x='price', y='bedroom')

# %%
data.price.hist(by=data.smoking, sharex=True, sharey=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-4f326116b0e4> in <module>()
# ----> 1 data.price.hist(by=data.smoking, sharex=True, sharey=True)
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2841                             **kwds)
#    2842
# -> 2843     if axes.ndim == 1 and len(axes) == 1:
#    2844         return axes[0]
#    2845     return axes
#
# AttributeError: 'AxesSubplot' object has no attribute 'ndim'

# %%
data.plot(kind='scatter', x='price', y='average_image_size', alpha = 0.2)

# %%
data.plot(kind='scatter', x='image_number', y='average_image_size', alpha = 0.2)

# %%
data.plot(kind='scatter', x='price', y='image_number', alpha=0.1)

# %%
data.average_image_size.hist()
