# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# %matplotlib inline

# %%
data = pd.read_csv(r'https://raw.githubusercontent.com/ajschumacher/gadsdata/master/salary/train.csv')

# %%
data.head()

SalaryNormalized
# Out:
#          Id                                              Title  \
# 0  12612628                        Engineering Systems Analyst
# 1  12612830                            Stress Engineer Glasgow
# 2  12612844                   Modelling and simulation analyst
# 3  12613049  Engineering Systems Analyst / Mathematical Mod...
# 4  12613647         Pioneer, Miser Engineering Systems Analyst
#
#                                      FullDescription  \
# 0  Engineering Systems Analyst Dorking Surrey Sal...
# 1  Stress Engineer Glasgow Salary **** to **** We...
# 2  Mathematical Modeller / Simulation Analyst / O...
# 3  Engineering Systems Analyst / Mathematical Mod...
# 4  Pioneer, Miser  Engineering Systems Analyst Do...
#
#                          LocationRaw LocationNormalized ContractType  \
# 0            Dorking, Surrey, Surrey            Dorking          NaN
# 1        Glasgow, Scotland, Scotland            Glasgow          NaN
# ...

# %%
data.describe()
# Out:
#                     Id  SalaryNormalized
# count     10000.000000      10000.000000
# mean   58883558.683700      31522.615600
# std     7383340.440499      16153.358741
# min    12612628.000000       5184.000000
# 25%    55408410.500000      20648.500000
# 50%    62005797.500000      27500.000000
# 75%    64796514.250000      37500.000000
# max    66190737.000000     172800.000000

# %%
data.groupby('ContractTime')['SalaryNormalized'].mean()
# Out:
# ContractTime
# contract     39951
# permanent    35240
# Name: SalaryNormalized, dtype: int64

# %%
def groupby_price(field):
    print data.groupby(field)['SalaryNormalized'].mean()

# %%
data.hist(alpha=0.5, bins=5, figsize=(15, 20))

# %%
data.groupby('Category')['SalaryNormalized'].mean().plot(figsize=(20,20))

# %%
for field in data.columns:
    print field
# Out:
# Id
# Title
# FullDescription
# LocationRaw
# LocationNormalized
# ContractType
# ContractTime
# Company
# Category
# SalaryRaw
# SalaryNormalized
# SourceName
