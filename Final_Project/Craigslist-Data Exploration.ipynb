# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r'C:\Users\alsherman\Desktop\GitHub\DataScience_GeneralAssembly\Data\Craigslist_Data_Apr_25.csv')

# %%
print data.columns
# Out:
# Index([u'Unnamed: 0', u'city', u'country', u'latitude', u'location_data_accuracy', u'longitude', u'state', u'availability', u'average_image_size', u'bathroom', u'bedroom', u'cat', u'date_available', u'description', u'dog', u'housing_type', u'image_number', u'laundry', u'parking', u'price', u'smoking', u'square_footage', u'url'], dtype='object')

# %%
data[0:1]
# Out:
#    Unnamed: 0       city country   latitude  location_data_accuracy  \
# 0  4949082219  Arlington      US  38.893049                      15
#
#    longitude state   availability  average_image_size bathroom  \
# 0  -77.08013    VA  available now                   0        1
#
#                          ...                          \
# 0                        ...
#
#                                          description  dog housing_type  \
# 0  \r\n        Hardwoods throughout, 2 walk-in cl...  NaN        condo
#
#   image_number laundry         parking  price smoking square_footage  \
# 0            0     NaN  street parking   1600     NaN            NaN
#
#                                                  url
# 0  http://washingtondc.craigslist.org/nva/apa/494...
#
# [1 rows x 23 columns]

# %% [markdown]
# ## Data Cleaning

# %%
#Clean up the Price Field

# Remove listings that do not have a listed price
data['price_to_keep'] = [price[0] for price in data.price]
data = data[data.price_to_keep == '$']
data.drop('price_to_keep', axis=1, inplace = True)

# Remove dollar symbol from price to change string to integer
data.price = [int(price.replace('$','')) for price in data.price]

# Remove outliers - possible data input mistakes from users
data = data[data.price < 10000]

# Remove listings with price listed as $1
#I hypothisize that this is to show up at the top when a user sorts by price
data = data[data.price > 1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-88-dfe6153fb7a3> in <module>()
#       2
#       3 # Remove listings that do not have a listed price
# ----> 4 data['price_to_keep'] = [price[0] for price in data.price]
#       5 data = data[data.price_to_keep == '$']
#       6 data.drop('price_to_keep', axis=1, inplace = True)
#
# IndexError: invalid index to scalar variable.

# %% [markdown]
# ## Data Exploration

# %%
data.describe()
# Out:
#          Unnamed: 0     latitude  location_data_accuracy    longitude  \
# count  2.421000e+03  1907.000000             1907.000000  1907.000000
# mean   4.990561e+09    38.846263                5.651285   -77.234776
# std    9.759583e+06     0.220438                8.130465     0.502180
# min    4.949082e+09    30.309300                0.000000   -97.724200
# 25%    4.990689e+09    38.811824                0.000000   -77.345100
# 50%    4.994725e+09    38.857063                0.000000   -77.148400
# 75%    4.995718e+09    38.887877               10.000000   -77.089600
# max    4.996378e+09    39.182100               22.000000   -75.661812
#
#        average_image_size      bedroom  image_number        price
# count         2421.000000  2421.000000   2421.000000  2421.000000
# mean         36496.235853     1.770756      8.083024  1825.073110
# std          27219.067919     1.067121      5.968385   638.245692
# min              0.000000     0.000000      0.000000   285.000000
# 25%          19285.000000     1.000000      4.000000  1400.000000
# 50%          30000.000000     2.000000      7.000000  1700.000000
# 75%          54000.000000     2.000000     11.000000  2100.000000
# max         135000.000000     7.000000     24.000000  6950.000000

# %%
data.plot(kind='scatter', x='price', y='image_number', alpha=0.1)

# %%
data.plot(kind='scatter', x='price', y='average_image_size', alpha = 0.2)

# %%
data.plot(kind='scatter', x='image_number', y='average_image_size', alpha = 0.2)

# %%
#data.groupby(data.city).price.plot(kind='bar')
data.price.hist(by=data.smoking)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-94a0ac5dc3fe> in <module>()
#       1 #data.groupby(data.city).price.plot(kind='bar')
# ----> 2 data.price.hist(by=data.smoking)
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2841                             **kwds)
#    2842
# -> 2843     if axes.ndim == 1 and len(axes) == 1:
#    2844         return axes[0]
#    2845     return axes
#
# AttributeError: 'AxesSubplot' object has no attribute 'ndim'

# %%
data.price.hist()

# %%
data.average_image_size.hist()

# %%
data.price.hist(by=data.bedroom, sharey=True,sharex=True, layout=(2,3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-23bc4ab57fcc> in <module>()
# ----> 1 data.price.hist(by=data.bedroom, sharey=True,sharex=True, layout=(2,3))
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2839         axes = grouped_hist(self, by=by, ax=ax, grid=grid, figsize=figsize, bins=bins,
#    2840                             xlabelsize=xlabelsize, xrot=xrot, ylabelsize=ylabelsize, yrot=yrot,
# -> 2841                             **kwds)
#    2842
#    2843     if axes.ndim == 1 and len(axes) == 1:
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in grouped_hist(data, column, by, ax, bins, figsize, layout, sharex, sharey, rot, grid, xlabelsize, xrot, ylabelsize, yrot, **kwargs)
#    2879     fig, axes = _grouped_plot(plot_group, data, column=column,
#    2880                               by=by, sharex=sharex, sharey=sharey, ax=ax,
# -> 2881                               figsize=figsize, layout=layout, rot=rot)
#    2882
#    2883     _set_ticks_props(axes, xlabelsize=xlabelsize, xrot=xrot,
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in _grouped_plot(plotf, data, column, by, numeric_only, figsize, sharex, sharey, layout, rot, ax, **kwargs)
#    2982     fig, axes = _subplots(naxes=naxes, figsize=figsize,
#    2983                           sharex=sharex, sharey=sharey, ax=ax,
# -> 2984                           layout=layout)
#    2985
#    2986     _axes = _flatten(axes)
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in _subplots(naxes, sharex, sharey, squeeze, subplot_kw, ax, layout, layout_type, **fig_kw)
#    3228             fig.clear()
#    3229
# -> 3230     nrows, ncols = _get_layout(naxes, layout=layout, layout_type=layout_type)
#    3231     nplots = nrows * ncols
#    3232
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in _get_layout(nplots, layout, layout_type)
#    3093         if nrows * ncols < nplots:
#    3094             raise ValueError('Layout of %sx%s must be larger than required size %s' %
# -> 3095                 (nrows, ncols, nplots))
#    3096
#    3097         return layout
#
# ValueError: Layout of 2x3 must be larger than required size 8

# %%
data.plot(kind='scatter', x='price', y='square_footage')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-4b5099a90810> in <module>()
# ----> 1 data.plot(kind='scatter', x='price', y='square_footage')
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2483                  yerr=yerr, xerr=xerr,
#    2484                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2485                  **kwds)
#    2486
#    2487
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2323         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2324
# -> 2325     plot_obj.generate()
#    2326     plot_obj.draw()
#    2327     return plot_obj.result
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in generate(self)
#     921         self._compute_plot_data()
#     922         self._setup_subplots()
# --> 923         self._make_plot()
#     924         self._add_table()
#     925         self._make_legend()
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\tools\plotting.pyc in _make_plot(self)
#    1444         else:
#    1445             label = None
# -> 1446         scatter = ax.scatter(data[x].values, data[y].values, c=c_values,
#    1447                              label=label, cmap=cmap, **self.kwds)
#    1448         if cb:
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\core\frame.pyc in __getitem__(self, key)
#    1785             return self._getitem_multilevel(key)
#    1786         else:
# -> 1787             return self._getitem_column(key)
#    1788
#    1789     def _getitem_column(self, key):
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\core\frame.pyc in _getitem_column(self, key)
#    1792         # get column
#    1793         if self.columns.is_unique:
# -> 1794             return self._get_item_cache(key)
#    1795
#    1796         # duplicate columns & possible reduce dimensionaility
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\core\generic.pyc in _get_item_cache(self, item)
#    1077         res = cache.get(item)
#    1078         if res is None:
# -> 1079             values = self._data.get(item)
#    1080             res = self._box_item_values(item, values)
#    1081             cache[item] = res
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\core\internals.pyc in get(self, item, fastpath)
#    2841
#    2842             if not isnull(item):
# -> 2843                 loc = self.items.get_loc(item)
#    2844             else:
#    2845                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\core\index.pyc in get_loc(self, key, method)
#    1435         """
#    1436         if method is None:
# -> 1437             return self._engine.get_loc(_values_from_object(key))
#    1438
#    1439         indexer = self.get_indexer([key], method=method)
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\index.pyd in pandas.index.IndexEngine.get_loc (pandas\index.c:3824)()
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\index.pyd in pandas.index.IndexEngine.get_loc (pandas\index.c:3704)()
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\hashtable.pyd in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12349)()
#
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas-0.16.0-py2.7-win-amd64.egg\pandas\hashtable.pyd in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:12300)()
#
# KeyError: 'square_footage'
