# %%
import requests # Helps construct the request to send to the API
import json # JSON helper functions
from bs4 import BeautifulSoup
import pandas as pd
import time
import ssl

# %%
data = pd.read_csv(r'C:\Users\alsherman\Desktop\GitHub\DataScience_GeneralAssembly\Data\Craigslist_Data_May_3_.csv')
location = zip(data['latitude'],data['longitude'])

# %%
data[0:1]
# Out:
#    Unnamed: 0 city country  latitude  location_data_accuracy  longitude state  \
# 0  4959351766  NaN     NaN       NaN                     NaN        NaN   NaN
#
#     availability  average_image_size bathroom  \
# 0  available now              270000        1
#
#                          ...                          dog housing_type  \
# 0                        ...                          NaN        condo
#
#   image_number laundry parking  price  smoking square_footage  \
# 0           18     NaN     NaN  $1310      NaN            NaN
#
#       time_of_posting                                                url
# 0  2015-04-01  2:44pm  http://washingtondc.craigslist.org/mld/apa/495...
#
# [1 rows x 24 columns]

# %%
#creates a url for each listing with the latitude, longitude, and search terms
def create_url(loc,types,keyword=''):
    
    url = r'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=' \
        + str(loc[0]) + ',' + str(loc[1]) + \
        '&radius=1610&rankby=prominence&' \
        + types + keyword + \
        'key=AIzaSyDg3TuDzV8ZIiWmxYTDT49Ix-uJG_nYS2w'

    return url

# %%
#returns a count of the provided search term (e.g. 20 nearby grocery stores)
def count_nearby_places(location, url):

    # Make the request
    response = requests.post(url)

    # place data in json object
    json_data = json.loads(response.text)

    # search through results and returns count of term
    place_count = 0
    name = ''
    for ind, search_term in enumerate(json_data['results']):
        place_count = ind + 1
        name = search_term['name']
    return str(place_count) + ' ' + name

# %%
grocery_list = []
gym_list = []
movies_theatre_list = []
train_station_list = []

for loc in location:
    #add nearby grocery stores
    types = 'types=grocery_or_supermarket&'
    url = create_url(loc, types)
    grocery_list.append(count_nearby_places(location, url))
    
    #add nearby gyms
    types = 'types=gym&'
    url = create_url(loc, types)
    gym_list.append(count_nearby_places(location, url))
    
    #add nearby movie theatres
    types = 'types=movie_theater&'
    url = create_url(loc, types)
    movies_theatre_list.append(count_nearby_places(location, url))
    
    #add nearby train stations
    types = 'types=train_station&'
    url = create_url(loc, types)
    train_station_list.append(count_nearby_places(location, url))
    
print grocery_list
print gym_list
print movies_theatre_list
print train_station_list
# Out:
# ['0 ', u'19 Alex Mart', '0 ', '0 ', u'20 Oasis Deli & Grocery']
# ['0 ', u'14 Sand & Steel CrossFit Fitness & Gym', '0 ', '0 ', u'20 F3 Training and Bodywork']
# ['0 ', u"2 Old Town Writer's Group", '0 ', '0 ', u'5 Farragut West Metro Station']
# ['0 ', u'7 Alexandria Amtrak', '0 ', '0 ', u'5 Dupont Circle Metro Station - South Entrance']

# %%
#create url for each specified market
for loc in location[0:1]:

    # 
    url = r'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=' + str(loc[0]) + ',' + str(loc[1]) + \
        '&radius=1610&rankby=prominence&types=grocery_or_supermarket&key=AIzaSyDg3TuDzV8ZIiWmxYTDT49Ix-uJG_nYS2w'

#barnes and nobles
#    url = r'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=' + str(loc[0]) + ',' + str(loc[1]) + \
#        '&radius=10000&rankby=prominence&keyword=barnesandnobles&types=book_store&key=AIzaSyDg3TuDzV8ZIiWmxYTDT49Ix-uJG_nYS2w'

    print url

    # Make the request
    response = requests.post(url)

    #place data in Beautiful soup object
    soup = BeautifulSoup(response.text)
    print soup
# Out:
#  https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.949864,-77.415054&radius=1610&rankby=prominence&types=grocery_or_supermarket&key=AIzaSyDg3TuDzV8ZIiWmxYTDT49Ix-uJG_nYS2w
# <html><body><p>{
#    "html_attributions" : [],
#    "results" : [
#       {
#          "geometry" : {
#             "location" : {
#                "lat" : 38.962637,
#                "lng" : -77.40065199999999
#             }
#          },
#          "icon" : "http://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#          "id" : "972b066aac46b37a8d916bd7afcc72e214807038",
#          "name" : "Giant",
#          "opening_hours" : {
#             "open_now" : true,
#             "weekday_text" : []
#          },
#          "photos" : [
#             {
#                "height" : 720,
#                "html_attributions" : [ "From a Google User" ],
# ...

# %%
import json
json_data = json.loads(response.text)
for i in json_data['results']:
    print i['types'], i['name']
    #i['rating']

'''
print json_data['results'][0]['rating']
print json_data['results'][0]['types']
print json_data['results'][0]['price_level']
print json_data['results'][0]['name']
print ''
print json_data
'''
# Out:
#  [u'pharmacy', u'grocery_or_supermarket', u'food', u'store', u'health', u'establishment'] Giant
# [u'grocery_or_supermarket', u'pharmacy', u'food', u'store', u'health', u'establishment'] Shoppers
# [u'grocery_or_supermarket', u'food', u'store', u'establishment'] Spices & Beyond
# [u'pharmacy', u'bakery', u'grocery_or_supermarket', u'store', u'health', u'food', u'establishment'] Shoppers Pharmacy
# [u'grocery_or_supermarket', u'food', u'store', u'establishment'] Priya Spices
# [u'grocery_or_supermarket', u'food', u'store', u'establishment'] Global Recovery Group LLC
# [u'grocery_or_supermarket', u'food', u'store', u'health', u'establishment'] Heartland Home Foods
# [u'grocery_or_supermarket', u'food', u'store', u'establishment'] Giant Food
# "\nprint json_data['results'][0]['rating']\nprint json_data['results'][0]['types']\nprint json_data['results'][0]['price_level']\nprint json_data['results'][0]['name']\nprint ''\nprint json_data\n"

# %%
#create url for each specified market
for loc in location[0:1]:

    # Search for nearby grocery stores within a one-mile (1610 meter) radius
    url = r'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=' + str(loc[0]) + ',' + str(loc[1]) + \
        '&radius=1610&rankby=prominence&types=grocery_or_supermarket&key=AIzaSyDg3TuDzV8ZIiWmxYTDT49Ix-uJG_nYS2w'

    # Make the request
    response = requests.post(url)

    # place data in json object
    json_data = json.loads(response.text)

    # search through results
    for ind, i in enumerate(json_data['results']):
        try:
            name = i['name']
        except: pass
        
        try:
            types = i['types']
        except: pass

        try:
            price_level = i['price_level']
        except: pass
        try:
            rating = i['rating']
        except: pass
        
        print ""
        grocery_count = ind
    print grocery_count
# Out:
# 7
# c:\Users\alsherman\AppData\Local\Continuum\Anaconda\lib\site-packages\requests\packages\urllib3\util\ssl_.py:79: InsecurePlatformWarning: A true SSLContext object is not available. This prevents urllib3 from configuring SSL appropriately and may cause certain SSL connections to fail. For more information, see https://urllib3.readthedocs.org/en/latest/security.html#insecureplatformwarning.
#   InsecurePlatformWarning
